# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Set Directory

# %%
os.getcwd()
# Out:
# '/Users/ofirklein/Desktop/NYC_Subway_DijkstraGTFS/data/dijkstra_data'

# %%
data_path = os.path.join(os.getcwd(),'nyc_subway')

# %%
os.chdir(data_path)

# %% [markdown]
# ____

# %%
#take txt file and make it into Pandas DF
stoptimes = pd.read_csv('stop_times.txt', sep=",")

# %%
stoptimes
# Out:
#                                            trip_id arrival_time  \
# 0           AFA19GEN-1037-Sunday-00_000600_1..S03R     00:06:00
# 1           AFA19GEN-1037-Sunday-00_000600_1..S03R     00:07:30
# 2           AFA19GEN-1037-Sunday-00_000600_1..S03R     00:09:00
# 3           AFA19GEN-1037-Sunday-00_000600_1..S03R     00:10:30
# 4           AFA19GEN-1037-Sunday-00_000600_1..S03R     00:12:00
# ...                                            ...          ...
# 541806  SIR-FA2017-SI017-Sunday-00_027100_SI..N03R     05:03:00
# 541807  SIR-FA2017-SI017-Sunday-00_027100_SI..N03R     05:06:00
# 541808  SIR-FA2017-SI017-Sunday-00_027100_SI..N03R     05:08:00
# 541809  SIR-FA2017-SI017-Sunday-00_027100_SI..N03R     05:10:00
# 541810  SIR-FA2017-SI017-Sunday-00_027100_SI..N03R     05:13:00
#
#        departure_time stop_id  stop_sequence  stop_headsign  pickup_type  \
# 0            00:06:00    101S              1            NaN            0
# 1            00:07:30    103S              2            NaN            0
# 2            00:09:00    104S              3            NaN            0
# 3            00:10:30    106S              4            NaN            0
# 4            00:12:00    107S              5            NaN            0
# ...               ...     ...            ...            ...          ...
# 541806       05:03:00    S27N             17            NaN            0
# 541807       05:06:00    S28N             18            NaN            0
# 541808       05:08:00    S29N             19            NaN            0
# 541809       05:10:00    S30N             20            NaN            0
# 541810       05:13:00    S31N             21            NaN            0
#
#         drop_off_type  shape_dist_traveled
# 0                   0                  NaN
# 1                   0                  NaN
# 2                   0                  NaN
# 3                   0                  NaN
# 4                   0                  NaN
# ...               ...                  ...
# 541806              0                  NaN
# 541807              0                  NaN
# 541808              0                  NaN
# 541809              0                  NaN
# 541810              0                  NaN
#
# [541811 rows x 9 columns]

# %%
columns_needed = ['trip_id','stop_sequence','stop_id','stop_id','arrival_time','departure_time']

# %%
stoptimes = stoptimes[columns_needed]

# %%
stop_times = stoptimes.sort_values(['trip_id', 'stop_sequence'], ascending = [1,1]).reset_index(drop = True)

# %%
#stop_times.drop(stop_times.columns[2], axis=1, inplace=True)

# %%
stop_times_columns = ['trip_id','stop_sequence','stop_id','stop_id_1','arrival_time','departure_time']

# %%
stop_times.columns = stop_times_columns

# %%
stop_times
# Out:
#                                             trip_id  stop_sequence stop_id  \
# 0            AFA19GEN-1037-Sunday-00_000600_1..S03R              1    101S
# 1            AFA19GEN-1037-Sunday-00_000600_1..S03R              2    103S
# 2            AFA19GEN-1037-Sunday-00_000600_1..S03R              3    104S
# 3            AFA19GEN-1037-Sunday-00_000600_1..S03R              4    106S
# 4            AFA19GEN-1037-Sunday-00_000600_1..S03R              5    107S
# ...                                             ...            ...     ...
# 541806  SIR-FA2017-SI017-Weekday-08_147100_SI..N03R             17    S27N
# 541807  SIR-FA2017-SI017-Weekday-08_147100_SI..N03R             18    S28N
# 541808  SIR-FA2017-SI017-Weekday-08_147100_SI..N03R             19    S29N
# 541809  SIR-FA2017-SI017-Weekday-08_147100_SI..N03R             20    S30N
# 541810  SIR-FA2017-SI017-Weekday-08_147100_SI..N03R             21    S31N
#
#        stop_id_1 arrival_time departure_time
# 0           101S     00:06:00       00:06:00
# 1           103S     00:07:30       00:07:30
# 2           104S     00:09:00       00:09:00
# 3           106S     00:10:30       00:10:30
# 4           107S     00:12:00       00:12:00
# ...          ...          ...            ...
# 541806      S27N     25:03:00       25:03:00
# 541807      S28N     25:06:00       25:06:00
# 541808      S29N     25:08:00       25:08:00
# 541809      S30N     25:10:00       25:10:00
# 541810      S31N     25:13:00       25:13:00
#
# [541811 rows x 6 columns]

# %% [markdown]
# ____

# %%
stops = pd.read_csv('stops.txt', sep=",")

# %%
stops_columns_needed = ['stop_id','stop_name','stop_lat','stop_lon','location_type','parent_station']

# %%
stops_df = stops[stops_columns_needed]

# %%
stops_df
# Out:
#      stop_id                    stop_name   stop_lat   stop_lon  \
# 0        101  Van Cortlandt Park - 242 St  40.889248 -73.898583
# 1       101N  Van Cortlandt Park - 242 St  40.889248 -73.898583
# 2       101S  Van Cortlandt Park - 242 St  40.889248 -73.898583
# 3        103                       238 St  40.884667 -73.900870
# 4       103N                       238 St  40.884667 -73.900870
# ...      ...                          ...        ...        ...
# 1498    S30N                Tompkinsville  40.636949 -74.074835
# 1499    S30S                Tompkinsville  40.636949 -74.074835
# 1500     S31                    St George  40.643748 -74.073643
# 1501    S31N                    St George  40.643748 -74.073643
# 1502    S31S                    St George  40.643748 -74.073643
#
#       location_type parent_station
# 0                 1            NaN
# 1                 0            101
# 2                 0            101
# 3                 1            NaN
# 4                 0            103
# ...             ...            ...
# 1498              0            S30
# 1499              0            S30
# 1500              1            NaN
# 1501              0            S31
# 1502              0            S31
#
# [1503 rows x 6 columns]

# %%
stop_times.trip_id.unique()
# Out:
# array(['AFA19GEN-1037-Sunday-00_000600_1..S03R',
#        'AFA19GEN-1037-Sunday-00_002600_1..S03R',
#        'AFA19GEN-1037-Sunday-00_004600_1..S03R', ...,
#        'SIR-FA2017-SI017-Weekday-08_141600_SI..S03R',
#        'SIR-FA2017-SI017-Weekday-08_144100_SI..N03R',
#        'SIR-FA2017-SI017-Weekday-08_147100_SI..N03R'], dtype=object)

# %%
sunday_trip = [i for i in stop_times.trip_id.unique() if 'AFA19GEN-1037-Sunday-00' in i]

# %%
len(sunday_trip)
# Out:
# 274

# %%
data = pd.DataFrame(columns = ['trip_id', 'trip_seg', 'fstop', 'tstop', 'time', 'dist'])

counter = 0

# %%
for trip in sunday_trip:
    trip_df = stop_times[stop_times.trip_id == trip] #filter to get all trips in that specific trip
    trip_id_list = [trip] * (trip_df.shape[0] - 1) # create list of trip id spanning how many trips exist
    trip_seg_list = list(trip_df.stop_sequence.values)[:-1] #list of all stop sequence [1...size(pd.Series)]
    fstop_list = list(trip_df.stop_id.values)[:-1] #list of arrays([stopID,StopID])
    tstop_list = list(trip_df.stop_id.values)[1:] #starts on n+1 to get destination 
    
    
    fstop_ts_list = list(trip_df.arrival_time.str.replace(' ','0').values)[:-1]
    tstop_ts_list = list(trip_df.arrival_time.str.replace(' ','0').values)[1:]
    
    
    
    new_trip_df = pd.DataFrame({'trip_id' : trip_id_list,
                                'trip_seg' : trip_seg_list,
                                'fstop' : fstop_list, 
                                'tstop' : tstop_list,
                                'fstop_ts' : fstop_ts_list,
                                'tstop_ts' : tstop_ts_list,
                                #'fstop_dist' : fstop_dist,
                                #'tstop_dist' : tstop_dist})
                                   })
    
    new_trip_df['fstop_ts_hr'] = new_trip_df.fstop_ts.str[:2].astype(int)
    new_trip_df['fstop_ts_min'] = new_trip_df.fstop_ts.str[3:5].astype(int)
    new_trip_df['fstop_ts_sec'] = new_trip_df.fstop_ts.str[6:8].astype(int)
    new_trip_df['fstop_ts'] = new_trip_df['fstop_ts_hr'] * 3600 + new_trip_df['fstop_ts_min'] * 60 + new_trip_df['fstop_ts_sec']
    
    new_trip_df['tstop_ts_hr'] = new_trip_df.tstop_ts.str[:2].astype(int)
    new_trip_df['tstop_ts_min'] = new_trip_df.tstop_ts.str[3:5].astype(int)
    new_trip_df['tstop_ts_sec'] = new_trip_df.tstop_ts.str[6:8].astype(int)
    new_trip_df['tstop_ts'] = new_trip_df['tstop_ts_hr'] * 3600 + new_trip_df['tstop_ts_min'] * 60 + new_trip_df['tstop_ts_sec']
    
    #print(new_trip_df)
    
    data = data.append(new_trip_df)
    
    counter = counter + 1
    
    print ('Progress : {}%'.format(np.round(counter*100/len(trip_list), 2)))
    print ('Processing : {} of {} trips'.format(counter, len(trip_list)))
# Out:
# Progress : 0.36%
# Processing : 1 of 274 trips
# Progress : 0.73%
# Processing : 2 of 274 trips
# Progress : 1.09%
# Processing : 3 of 274 trips
# Progress : 1.46%
# Processing : 4 of 274 trips
# Progress : 1.82%
# Processing : 5 of 274 trips
# Progress : 2.19%
# Processing : 6 of 274 trips
# Progress : 2.55%
# Processing : 7 of 274 trips
# Progress : 2.92%
# Processing : 8 of 274 trips
# Progress : 3.28%
# Processing : 9 of 274 trips
# Progress : 3.65%
# Processing : 10 of 274 trips
# Progress : 4.01%
# Processing : 11 of 274 trips
# Progress : 4.38%
# Processing : 12 of 274 trips
# Progress : 4.74%
# Processing : 13 of 274 trips
# Progress : 5.11%
# Processing : 14 of 274 trips
# Progress : 5.47%
# Processing : 15 of 274 trips
# Progress : 5.84%
# Processing : 16 of 274 trips
# Progress : 6.2%
# Processing : 17 of 274 trips
# Progress : 6.57%
# Processing : 18 of 274 trips
# Progress : 6.93%
# Processing : 19 of 274 trips
# Progress : 7.3%
# Processing : 20 of 274 trips
# Progress : 7.66%
# Processing : 21 of 274 trips
# Progress : 8.03%
# Processing : 22 of 274 trips
# Progress : 8.39%
# Processing : 23 of 274 trips
# Progress : 8.76%
# Processing : 24 of 274 trips
# Progress : 9.12%
# Processing : 25 of 274 trips
# Progress : 9.49%
# Processing : 26 of 274 trips
# Progress : 9.85%
# Processing : 27 of 274 trips
# Progress : 10.22%
# Processing : 28 of 274 trips
# Progress : 10.58%
# Processing : 29 of 274 trips
# Progress : 10.95%
# Processing : 30 of 274 trips
# Progress : 11.31%
# Processing : 31 of 274 trips
# Progress : 11.68%
# Processing : 32 of 274 trips
# Progress : 12.04%
# Processing : 33 of 274 trips
# Progress : 12.41%
# Processing : 34 of 274 trips
# Progress : 12.77%
# Processing : 35 of 274 trips
# Progress : 13.14%
# Processing : 36 of 274 trips
# Progress : 13.5%
# Processing : 37 of 274 trips
# Progress : 13.87%
# Processing : 38 of 274 trips
# Progress : 14.23%
# Processing : 39 of 274 trips
# Progress : 14.6%
# Processing : 40 of 274 trips
# Progress : 14.96%
# Processing : 41 of 274 trips
# Progress : 15.33%
# Processing : 42 of 274 trips
# Progress : 15.69%
# Processing : 43 of 274 trips
# Progress : 16.06%
# Processing : 44 of 274 trips
# Progress : 16.42%
# Processing : 45 of 274 trips
# Progress : 16.79%
# Processing : 46 of 274 trips
# Progress : 17.15%
# Processing : 47 of 274 trips
# Progress : 17.52%
# Processing : 48 of 274 trips
# Progress : 17.88%
# Processing : 49 of 274 trips
# Progress : 18.25%
# Processing : 50 of 274 trips
# Progress : 18.61%
# Processing : 51 of 274 trips
# Progress : 18.98%
# Processing : 52 of 274 trips
# Progress : 19.34%
# Processing : 53 of 274 trips
# Progress : 19.71%
# Processing : 54 of 274 trips
# Progress : 20.07%
# Processing : 55 of 274 trips
# Progress : 20.44%
# Processing : 56 of 274 trips
# Progress : 20.8%
# Processing : 57 of 274 trips
# Progress : 21.17%
# Processing : 58 of 274 trips
# Progress : 21.53%
# Processing : 59 of 274 trips
# Progress : 21.9%
# Processing : 60 of 274 trips
# Progress : 22.26%
# Processing : 61 of 274 trips
# Progress : 22.63%
# Processing : 62 of 274 trips
# Progress : 22.99%
# Processing : 63 of 274 trips
# Progress : 23.36%
# Processing : 64 of 274 trips
# Progress : 23.72%
# Processing : 65 of 274 trips
# Progress : 24.09%
# Processing : 66 of 274 trips
# Progress : 24.45%
# Processing : 67 of 274 trips
# Progress : 24.82%
# Processing : 68 of 274 trips
# Progress : 25.18%
# Processing : 69 of 274 trips
# Progress : 25.55%
# Processing : 70 of 274 trips
# Progress : 25.91%
# Processing : 71 of 274 trips
# Progress : 26.28%
# Processing : 72 of 274 trips
# Progress : 26.64%
# Processing : 73 of 274 trips
# Progress : 27.01%
# Processing : 74 of 274 trips
# Progress : 27.37%
# Processing : 75 of 274 trips
# Progress : 27.74%
# Processing : 76 of 274 trips
# Progress : 28.1%
# Processing : 77 of 274 trips
# Progress : 28.47%
# Processing : 78 of 274 trips
# Progress : 28.83%
# Processing : 79 of 274 trips
# Progress : 29.2%
# Processing : 80 of 274 trips
# Progress : 29.56%
# Processing : 81 of 274 trips
# Progress : 29.93%
# Processing : 82 of 274 trips
# Progress : 30.29%
# Processing : 83 of 274 trips
# Progress : 30.66%
# Processing : 84 of 274 trips
# Progress : 31.02%
# Processing : 85 of 274 trips
# Progress : 31.39%
# Processing : 86 of 274 trips
# Progress : 31.75%
# Processing : 87 of 274 trips
# Progress : 32.12%
# Processing : 88 of 274 trips
# Progress : 32.48%
# Processing : 89 of 274 trips
# Progress : 32.85%
# Processing : 90 of 274 trips
# Progress : 33.21%
# Processing : 91 of 274 trips
# Progress : 33.58%
# Processing : 92 of 274 trips
# Progress : 33.94%
# Processing : 93 of 274 trips
# Progress : 34.31%
# Processing : 94 of 274 trips
# Progress : 34.67%
# Processing : 95 of 274 trips
# Progress : 35.04%
# Processing : 96 of 274 trips
# Progress : 35.4%
# Processing : 97 of 274 trips
# Progress : 35.77%
# Processing : 98 of 274 trips
# Progress : 36.13%
# Processing : 99 of 274 trips
# Progress : 36.5%
# Processing : 100 of 274 trips
# Progress : 36.86%
# Processing : 101 of 274 trips
# Progress : 37.23%
# Processing : 102 of 274 trips
# Progress : 37.59%
# Processing : 103 of 274 trips
# Progress : 37.96%
# Processing : 104 of 274 trips
# Progress : 38.32%
# Processing : 105 of 274 trips
# Progress : 38.69%
# Processing : 106 of 274 trips
# Progress : 39.05%
# Processing : 107 of 274 trips
# Progress : 39.42%
# Processing : 108 of 274 trips
# Progress : 39.78%
# Processing : 109 of 274 trips
# Progress : 40.15%
# Processing : 110 of 274 trips
# Progress : 40.51%
# Processing : 111 of 274 trips
# Progress : 40.88%
# Processing : 112 of 274 trips
# Progress : 41.24%
# Processing : 113 of 274 trips
# Progress : 41.61%
# Processing : 114 of 274 trips
# Progress : 41.97%
# Processing : 115 of 274 trips
# Progress : 42.34%
# Processing : 116 of 274 trips
# Progress : 42.7%
# Processing : 117 of 274 trips
# Progress : 43.07%
# Processing : 118 of 274 trips
# Progress : 43.43%
# Processing : 119 of 274 trips
# Progress : 43.8%
# Processing : 120 of 274 trips
# Progress : 44.16%
# Processing : 121 of 274 trips
# Progress : 44.53%
# Processing : 122 of 274 trips
# Progress : 44.89%
# Processing : 123 of 274 trips
# Progress : 45.26%
# Processing : 124 of 274 trips
# Progress : 45.62%
# Processing : 125 of 274 trips
# Progress : 45.99%
# Processing : 126 of 274 trips
# Progress : 46.35%
# Processing : 127 of 274 trips
# Progress : 46.72%
# Processing : 128 of 274 trips
# Progress : 47.08%
# Processing : 129 of 274 trips
# Progress : 47.45%
# Processing : 130 of 274 trips
# Progress : 47.81%
# Processing : 131 of 274 trips
# Progress : 48.18%
# Processing : 132 of 274 trips
# Progress : 48.54%
# Processing : 133 of 274 trips
# Progress : 48.91%
# Processing : 134 of 274 trips
# Progress : 49.27%
# Processing : 135 of 274 trips
# Progress : 49.64%
# Processing : 136 of 274 trips
# Progress : 50.0%
# Processing : 137 of 274 trips
# Progress : 50.36%
# Processing : 138 of 274 trips
# Progress : 50.73%
# Processing : 139 of 274 trips
# Progress : 51.09%
# Processing : 140 of 274 trips
# Progress : 51.46%
# Processing : 141 of 274 trips
# Progress : 51.82%
# Processing : 142 of 274 trips
# Progress : 52.19%
# Processing : 143 of 274 trips
# Progress : 52.55%
# Processing : 144 of 274 trips
# Progress : 52.92%
# Processing : 145 of 274 trips
# Progress : 53.28%
# Processing : 146 of 274 trips
# Progress : 53.65%
# Processing : 147 of 274 trips
# Progress : 54.01%
# Processing : 148 of 274 trips
# Progress : 54.38%
# Processing : 149 of 274 trips
# Progress : 54.74%
# Processing : 150 of 274 trips
# Progress : 55.11%
# Processing : 151 of 274 trips
# Progress : 55.47%
# Processing : 152 of 274 trips
# Progress : 55.84%
# Processing : 153 of 274 trips
# Progress : 56.2%
# Processing : 154 of 274 trips
# Progress : 56.57%
# Processing : 155 of 274 trips
# Progress : 56.93%
# Processing : 156 of 274 trips
# Progress : 57.3%
# Processing : 157 of 274 trips
# Progress : 57.66%
# Processing : 158 of 274 trips
# Progress : 58.03%
# Processing : 159 of 274 trips
# Progress : 58.39%
# Processing : 160 of 274 trips
# Progress : 58.76%
# Processing : 161 of 274 trips
# Progress : 59.12%
# Processing : 162 of 274 trips
# Progress : 59.49%
# Processing : 163 of 274 trips
# Progress : 59.85%
# Processing : 164 of 274 trips
# Progress : 60.22%
# Processing : 165 of 274 trips
# Progress : 60.58%
# Processing : 166 of 274 trips
# Progress : 60.95%
# Processing : 167 of 274 trips
# Progress : 61.31%
# Processing : 168 of 274 trips
# Progress : 61.68%
# Processing : 169 of 274 trips
# Progress : 62.04%
# Processing : 170 of 274 trips
# Progress : 62.41%
# Processing : 171 of 274 trips
# Progress : 62.77%
# Processing : 172 of 274 trips
# Progress : 63.14%
# Processing : 173 of 274 trips
# Progress : 63.5%
# Processing : 174 of 274 trips
# Progress : 63.87%
# Processing : 175 of 274 trips
# Progress : 64.23%
# Processing : 176 of 274 trips
# Progress : 64.6%
# Processing : 177 of 274 trips
# Progress : 64.96%
# Processing : 178 of 274 trips
# Progress : 65.33%
# Processing : 179 of 274 trips
# Progress : 65.69%
# Processing : 180 of 274 trips
# Progress : 66.06%
# Processing : 181 of 274 trips
# Progress : 66.42%
# Processing : 182 of 274 trips
# Progress : 66.79%
# Processing : 183 of 274 trips
# Progress : 67.15%
# Processing : 184 of 274 trips
# Progress : 67.52%
# Processing : 185 of 274 trips
# Progress : 67.88%
# Processing : 186 of 274 trips
# Progress : 68.25%
# Processing : 187 of 274 trips
# Progress : 68.61%
# Processing : 188 of 274 trips
# Progress : 68.98%
# Processing : 189 of 274 trips
# Progress : 69.34%
# Processing : 190 of 274 trips
# Progress : 69.71%
# Processing : 191 of 274 trips
# Progress : 70.07%
# Processing : 192 of 274 trips
# Progress : 70.44%
# Processing : 193 of 274 trips
# Progress : 70.8%
# Processing : 194 of 274 trips
# Progress : 71.17%
# Processing : 195 of 274 trips
# Progress : 71.53%
# Processing : 196 of 274 trips
# Progress : 71.9%
# Processing : 197 of 274 trips
# Progress : 72.26%
# Processing : 198 of 274 trips
# Progress : 72.63%
# Processing : 199 of 274 trips
# Progress : 72.99%
# Processing : 200 of 274 trips
# Progress : 73.36%
# Processing : 201 of 274 trips
# Progress : 73.72%
# Processing : 202 of 274 trips
# Progress : 74.09%
# Processing : 203 of 274 trips
# Progress : 74.45%
# Processing : 204 of 274 trips
# Progress : 74.82%
# Processing : 205 of 274 trips
# Progress : 75.18%
# Processing : 206 of 274 trips
# Progress : 75.55%
# Processing : 207 of 274 trips
# Progress : 75.91%
# Processing : 208 of 274 trips
# Progress : 76.28%
# Processing : 209 of 274 trips
# Progress : 76.64%
# Processing : 210 of 274 trips
# Progress : 77.01%
# Processing : 211 of 274 trips
# Progress : 77.37%
# Processing : 212 of 274 trips
# Progress : 77.74%
# Processing : 213 of 274 trips
# Progress : 78.1%
# Processing : 214 of 274 trips
# Progress : 78.47%
# Processing : 215 of 274 trips
# Progress : 78.83%
# Processing : 216 of 274 trips
# Progress : 79.2%
# Processing : 217 of 274 trips
# Progress : 79.56%
# Processing : 218 of 274 trips
# Progress : 79.93%
# Processing : 219 of 274 trips
# Progress : 80.29%
# Processing : 220 of 274 trips
# Progress : 80.66%
# Processing : 221 of 274 trips
# Progress : 81.02%
# Processing : 222 of 274 trips
# Progress : 81.39%
# Processing : 223 of 274 trips
# Progress : 81.75%
# Processing : 224 of 274 trips
# Progress : 82.12%
# Processing : 225 of 274 trips
# Progress : 82.48%
# Processing : 226 of 274 trips
# Progress : 82.85%
# Processing : 227 of 274 trips
# Progress : 83.21%
# Processing : 228 of 274 trips
# Progress : 83.58%
# Processing : 229 of 274 trips
# Progress : 83.94%
# Processing : 230 of 274 trips
# Progress : 84.31%
# Processing : 231 of 274 trips
# Progress : 84.67%
# Processing : 232 of 274 trips
# Progress : 85.04%
# Processing : 233 of 274 trips
# Progress : 85.4%
# Processing : 234 of 274 trips
# Progress : 85.77%
# Processing : 235 of 274 trips
# Progress : 86.13%
# Processing : 236 of 274 trips
# Progress : 86.5%
# Processing : 237 of 274 trips
# Progress : 86.86%
# Processing : 238 of 274 trips
# Progress : 87.23%
# Processing : 239 of 274 trips
# Progress : 87.59%
# Processing : 240 of 274 trips
# Progress : 87.96%
# Processing : 241 of 274 trips
# Progress : 88.32%
# Processing : 242 of 274 trips
# Progress : 88.69%
# Processing : 243 of 274 trips
# Progress : 89.05%
# Processing : 244 of 274 trips
# Progress : 89.42%
# Processing : 245 of 274 trips
# Progress : 89.78%
# Processing : 246 of 274 trips
# Progress : 90.15%
# Processing : 247 of 274 trips
# Progress : 90.51%
# Processing : 248 of 274 trips
# Progress : 90.88%
# Processing : 249 of 274 trips
# Progress : 91.24%
# Processing : 250 of 274 trips
# Progress : 91.61%
# Processing : 251 of 274 trips
# Progress : 91.97%
# Processing : 252 of 274 trips
# Progress : 92.34%
# Processing : 253 of 274 trips
# Progress : 92.7%
# Processing : 254 of 274 trips
# Progress : 93.07%
# Processing : 255 of 274 trips
# Progress : 93.43%
# Processing : 256 of 274 trips
# Progress : 93.8%
# Processing : 257 of 274 trips
# Progress : 94.16%
# Processing : 258 of 274 trips
# Progress : 94.53%
# Processing : 259 of 274 trips
# Progress : 94.89%
# Processing : 260 of 274 trips
# Progress : 95.26%
# Processing : 261 of 274 trips
# Progress : 95.62%
# Processing : 262 of 274 trips
# Progress : 95.99%
# Processing : 263 of 274 trips
# Progress : 96.35%
# Processing : 264 of 274 trips
# Progress : 96.72%
# Processing : 265 of 274 trips
# Progress : 97.08%
# Processing : 266 of 274 trips
# Progress : 97.45%
# Processing : 267 of 274 trips
# Progress : 97.81%
# Processing : 268 of 274 trips
# Progress : 98.18%
# Processing : 269 of 274 trips
# Progress : 98.54%
# Processing : 270 of 274 trips
# Progress : 98.91%
# Processing : 271 of 274 trips
# Progress : 99.27%
# Processing : 272 of 274 trips
# Progress : 99.64%
# Processing : 273 of 274 trips
# Progress : 100.0%
# Processing : 274 of 274 trips

# %%
data['time_total'] = (data['tstop_ts'] - data['fstop_ts'])

# %%
#data.trip_id = data.trip_id.astype(int)
data['time'] = (data['tstop_ts'] - data['fstop_ts'])
data.trip_seg = data.trip_seg.astype(int)
data.time = data.time.astype(int)
data.dist = data.dist.astype(float)
#data['stop_dummy'] = data.fstop[0].astype(str) + '-' + data.tstop[0].astype(str)

# %% [markdown]
# ___

# %%
col_need = ['trip_seg','fstop','tstop']

# %%
data_fil = data[col_need]

# %%
data_fil
# Out:
#     trip_seg fstop tstop
# 0          1  101S  103S
# 1          2  103S  104S
# 2          3  104S  106S
# 3          4  106S  107S
# 4          5  107S  108S
# ..       ...   ...   ...
# 32        33  108N  107N
# 33        34  107N  106N
# 34        35  106N  104N
# 35        36  104N  103N
# 36        37  103N  101N
#
# [10138 rows x 3 columns]

# %% [markdown]
# ____

# %%
fil_stops = stops[['stop_id','stop_name','stop_lat','stop_lon']]

fstop_merge = stops[['stop_id','stop_name','stop_lat','stop_lon']]
tstop_merge = stops[['stop_id','stop_name','stop_lat','stop_lon']]

# %%
fstop_col = ['fstop_id', 'fstop_name', 'fstop_lat', 'fstop_lon']
tstop_col = ['tstop_id', 'tstop_name', 'tstop_lat', 'tstop_lon']

fstop_merge.columns = fstop_col
tstop_merge.columns = tstop_col

# %%
tstop_merge
# Out:
#      tstop_id                   tstop_name  tstop_lat  tstop_lon
# 0         101  Van Cortlandt Park - 242 St  40.889248 -73.898583
# 1        101N  Van Cortlandt Park - 242 St  40.889248 -73.898583
# 2        101S  Van Cortlandt Park - 242 St  40.889248 -73.898583
# 3         103                       238 St  40.884667 -73.900870
# 4        103N                       238 St  40.884667 -73.900870
# ...       ...                          ...        ...        ...
# 1498     S30N                Tompkinsville  40.636949 -74.074835
# 1499     S30S                Tompkinsville  40.636949 -74.074835
# 1500      S31                    St George  40.643748 -74.073643
# 1501     S31N                    St George  40.643748 -74.073643
# 1502     S31S                    St George  40.643748 -74.073643
#
# [1503 rows x 4 columns]

# %%
data_fil
# Out:
#     trip_seg fstop tstop
# 0          1  101S  103S
# 1          2  103S  104S
# 2          3  104S  106S
# 3          4  106S  107S
# 4          5  107S  108S
# ..       ...   ...   ...
# 32        33  108N  107N
# 33        34  107N  106N
# 34        35  106N  104N
# 35        36  104N  103N
# 36        37  103N  101N
#
# [10138 rows x 3 columns]

# %%
fstop_data = pd.merge(data_fil,
                      tstop_merge,
                      left_on='fstop',
                      right_on='fstop_id',
                        )

# %%
data_merged = pd.merge(fstop_data,
                      tstop_merge,
                      left_on='tstop',
                      right_on='tstop_id',
                        )

# %%
subway_1line = data_merged[['trip_seg','fstop','tstop','fstop_name','tstop_name','fstop_lat','fstop_lon','tstop_lat','tstop_lon']]

# %%
#subway_1line.to_json(orient="records")
# Out:
# '[{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fstop":"101S","tstop":"103S","fstop_name":"Van Cortlandt Park - 242 St","tstop_name":"238 St","fstop_lat":40.889248,"fstop_lon":-73.898583,"tstop_lat":40.884667,"tstop_lon":-73.90087},{"trip_seg":1,"fst ...

# %%
#routes = pd.read_csv('routes.txt',sep=',')
#trips = pd.read_csv('trips.txt',sep=',')

# %%
south_trips= subway_1line[subway_1line['fstop'].str.lower().str.contains('s')]
north_trips= subway_1line[subway_1line['fstop'].str.lower().str.contains('n')]

# %%
north_trips = north_trips.drop_duplicates(subset=['trip_seg','fstop','tstop','fstop_name','tstop_name'])
south_trips = south_trips.drop_duplicates(subset=['trip_seg','fstop','tstop','fstop_name','tstop_name'])

# %%
fil_north_trip = north_trips[['trip_seg','fstop','tstop','fstop_name','fstop_lat','fstop_lon']].reset_index().drop(columns='index')

fil_south_trip = south_trips[['trip_seg','fstop','tstop','tstop_name','tstop_lat','tstop_lon']].reset_index().drop(columns='index')

# %%
fil_north_trip
# Out:
#     trip_seg fstop tstop                    fstop_name  fstop_lat  fstop_lon
# 0          1  142N  139N                   South Ferry  40.702068 -74.013664
# 1          2  139N  138N                     Rector St  40.707513 -74.013783
# 2          3  138N  137N                  Cortlandt St  40.711835 -74.012188
# 3          4  137N  136N                   Chambers St  40.715478 -74.009266
# 4          5  136N  135N                   Franklin St  40.719318 -74.006886
# 5          6  135N  134N                      Canal St  40.722854 -74.006277
# 6          7  134N  133N                    Houston St  40.728251 -74.005367
# 7          8  133N  132N  Christopher St - Sheridan Sq  40.733422 -74.002906
# 8          9  132N  131N                         14 St  40.737826 -74.000201
# 9         10  131N  130N                         18 St  40.741040 -73.997871
# 10        11  130N  129N                         23 St  40.744081 -73.995657
# 11        12  129N  128N                         28 St  40.747215 -73.993365
# 12        13  128N  127N          34 St - Penn Station  40.750373 -73.991057
# 13        14  127N  126N              Times Sq - 42 St  40.755290 -73.987495
# 14        15  126N  125N                         50 St  40.761728 -73.983849
# 15        16  125N  124N       59 St - Columbus Circle  40.768247 -73.981929
# 16        17  124N  123N        66 St - Lincoln Center  40.773440 -73.982209
# 17        18  123N  122N                         72 St  40.778453 -73.981970
# 18        19  122N  121N                         79 St  40.783934 -73.979917
# 19        20  121N  120N                         86 St  40.788644 -73.976218
# 20        21  120N  119N                         96 St  40.793919 -73.972323
# 21        22  119N  118N                        103 St  40.799446 -73.968379
# 22        23  118N  117N       Cathedral Pkwy (110 St)  40.803967 -73.966847
# 23        24  117N  116N  116 St - Columbia University  40.807722 -73.964110
# 24        25  116N  115N                        125 St  40.815581 -73.958372
# 25        26  115N  114N         137 St - City College  40.822008 -73.953676
# 26        27  114N  113N                        145 St  40.826551 -73.950360
# 27        28  113N  112N                        157 St  40.834041 -73.944890
# 28        29  112N  111N       168 St - Washington Hts  40.840556 -73.940133
# 29        30  111N  110N                        181 St  40.849505 -73.933596
# 30        31  110N  109N                        191 St  40.855225 -73.929412
# 31        32  109N  108N                    Dyckman St  40.860531 -73.925536
# 32        33  108N  107N                        207 St  40.864621 -73.918822
# 33        34  107N  106N                        215 St  40.869444 -73.915279
# 34        35  106N  104N          Marble Hill - 225 St  40.874561 -73.909831
# 35        36  104N  103N                        231 St  40.878856 -73.904834
# 36        37  103N  101N                        238 St  40.884667 -73.900870
