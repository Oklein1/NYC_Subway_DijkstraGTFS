# %%
import geopandas

# %%
stops_url = '/Users/ofirklein/Desktop/NYC_Subway_DijkstraGTFS/data/stops.geojson'
stops = geopandas.read_file(stops_url)

# %%
stops
# Out:
#     stop_id                    stop_name   stop_lat   stop_lon trains  \
# 0       101  Van Cortlandt Park - 242 St  40.889248 -73.898583      1
# 1       103                       238 St  40.884667 -73.900870      1
# 2       104                       231 St  40.878856 -73.904834      1
# 3       201           Wakefield - 241 St  40.903125 -73.850620      2
# 4       204                    Nereid Av  40.898379 -73.854376    2 5
# ..      ...                          ...        ...        ...    ...
# 488     S27                     Grasmere  40.603117 -74.084087    SIR
# 489     S28                      Clifton  40.621319 -74.071402    SIR
# 490     S29                    Stapleton  40.627915 -74.075162    SIR
# 491     S30                Tompkinsville  40.636949 -74.074835    SIR
# 492     S31                    St George  40.643748 -74.073643    SIR
#
#     structure stop_id2  GEOID         NAMELSAD                    geometry
# ...
